# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.layers import Input,Conv2D,MaxPooling2D,Dropout,Flatten,Dense,Activation,BatchNormalization,add
from tensorflow.keras.models  import Model,Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input
import os

# %%
# Initializing VGG16 model
vgg = VGG16(weights= 'imagenet', include_top = False, input_shape = (224,224,3))
# include_top = False (loads full model without LAST fully connected layers) 


for layer in vgg.layers:
    layer.trainable = False #making all the layers non-trainable
    
    
# Flattening out the last layer    
x = Flatten()(vgg.output)


# Adding a dense layer
# To determine if the person is Healthy of Pneumonitic
predictions = Dense(2,activation='softmax')(x) 


model = Model(inputs=vgg.input, outputs=predictions)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Getting current directory
base_dir = os.getcwd() 

# Defining the input shape
target_shape = (224,224) 

train_dir = base_dir+"\\chest_xray\\train" # 
val_dir = base_dir+"\\chest_xray\\val"     # -- Directories for data
test_dir = base_dir+"\\chest_xray\\test"   #

# %%
vgg = VGG16(weights= 'imagenet', include_top = False, input_shape = (224,224,3))
for layer in vgg.layers:
    layer.trainable = False # Making all the layers non-trainable

# %%
# Flattening out the last layer

x = Flatten()(vgg.output) 
predictions = Dense(2,activation='softmax')(x) #Dense layer to predict wether their is pneumonia or not
model = Model(inputs=vgg.input, outputs=predictions)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Making the data loader for training data
train_gen = ImageDataGenerator(rescale=1/255.0,
                               horizontal_flip=True,
                               zoom_range=0.2,
                               shear_range=0.2) 


# Making the data loader for validation data
test_gen = ImageDataGenerator(rescale=1/255.0) 


# Function to make iterable object for training
train_data_gen = train_gen.flow_from_directory(train_dir,
                                               target_shape,
                                               batch_size=16,
                                               class_mode='categorical') 

# Function to make iterable object for training
test_data_gen = train_gen.flow_from_directory(test_dir,
                                               target_shape,
                                               batch_size=16,
                                               class_mode='categorical')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
hist = model.fit_generator(train_data_gen,
        steps_per_epoch=20,
        epochs=20,
        validation_data=test_data_gen,
        validation_steps=10)
# Out:
# C:\Users\nloke\AppData\Local\Temp\ipykernel_2296\440662495.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data_gen,
# Epoch 1/20
# 20/20 [==============================] - 114s 6s/step - loss: 0.7681 - accuracy: 0.7469 - val_loss: 0.3011 - val_accuracy: 0.8687
# Epoch 2/20
# 20/20 [==============================] - 107s 5s/step - loss: 0.2562 - accuracy: 0.9031 - val_loss: 0.6206 - val_accuracy: 0.7750
# Epoch 3/20
# 20/20 [==============================] - 105s 5s/step - loss: 0.1522 - accuracy: 0.9438 - val_loss: 0.7498 - val_accuracy: 0.7375
# Epoch 4/20
# 20/20 [==============================] - 147s 8s/step - loss: 0.1223 - accuracy: 0.9563 - val_loss: 0.3807 - val_accuracy: 0.8687
# Epoch 5/20
# 20/20 [==============================] - 68s 3s/step - loss: 0.2240 - accuracy: 0.9125 - val_loss: 0.5398 - val_accuracy: 0.8313
# Epoch 6/20
# 20/20 [==============================] - 71s 4s/step - loss: 0.1952 - accuracy: 0.9250 - val_loss: 0.7352 - val_accuracy: 0.7688
# Epoch 7/20
# 20/20 [==============================] - 65s 3s/step - loss: 0.1191 - accuracy: 0.9531 - val_loss: 0.7036 - val_accuracy: 0.7625
# Epoch 8/20
# 20/20 [==============================] - 76s 4s/step - loss: 0.1189 - accuracy: 0.9469 - val_loss: 0.1995 - val_accuracy: 0.9375
# Epoch 9/20
# 20/20 [==============================] - 123s 6s/step - loss: 0.1220 - accuracy: 0.9469 - val_loss: 0.2246 - val_accuracy: 0.9250
# Epoch 10/20
# 20/20 [==============================] - 126s 6s/step - loss: 0.1429 - accuracy: 0.9500 - val_loss: 0.9297 - val_accuracy: 0.7063
# Epoch 11/20
# 20/20 [==============================] - 124s 6s/step - loss: 0.1657 - accuracy: 0.9375 - val_loss: 0.7334 - val_accuracy: 0.7812
# Epoch 12/20
# 20/20 [==============================] - 128s 6s/step - loss: 0.2032 - accuracy: 0.9344 - val_loss: 0.3252 - val_accuracy: 0.8813
# Epoch 13/20
# 20/20 [==============================] - 126s 6s/step - loss: 0.1551 - accuracy: 0.9406 - val_loss: 0.4260 - val_accuracy: 0.8500
# Epoch 14/20
# 20/20 [==============================] - 146s 7s/step - loss: 0.1009 - accuracy: 0.9594 - val_loss: 0.6121 - val_accuracy: 0.8188
# Epoch 15/20
# 20/20 [==============================] - 135s 7s/step - loss: 0.1600 - accuracy: 0.9469 - val_loss: 0.3890 - val_accuracy: 0.8875
# Epoch 16/20
# 20/20 [==============================] - 131s 7s/step - loss: 0.0815 - accuracy: 0.9750 - val_loss: 0.3435 - val_accuracy: 0.8938
# Epoch 17/20
# 20/20 [==============================] - 126s 6s/step - loss: 0.0870 - accuracy: 0.9719 - val_loss: 0.6785 - val_accuracy: 0.7875
# Epoch 18/20
# 20/20 [==============================] - 119s 6s/step - loss: 0.1913 - accuracy: 0.9438 - val_loss: 0.5188 - val_accuracy: 0.8375
# Epoch 19/20
# 20/20 [==============================] - 120s 6s/step - loss: 0.1088 - accuracy: 0.9531 - val_loss: 0.3460 - val_accuracy: 0.8813
# Epoch 20/20
# 20/20 [==============================] - 121s 6s/step - loss: 0.1198 - accuracy: 0.9531 - val_loss: 1.3894 - val_accuracy: 0.6875

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(hist.history["loss"], label="train_loss")
plt.plot(hist.history["val_loss"], label="val_loss")
plt.plot(hist.history["accuracy"], label="train_acc")
plt.plot(hist.history["val_accuracy"], label="val_acc")
plt.title("Model Training")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig("epochs.png")

# %%
#model.save('model.h5')
